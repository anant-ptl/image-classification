# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("./photos/virat_kohli/download (5).jpeg")
img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img)

# %% [markdown]
# #### removing 3rd dim

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (183, 275)

# %%
plt.imshow(gray , cmap='gray')

# %%
gray
# Out:
# array([[187, 191, 195, ..., 186, 155, 127],
#        [187, 192, 195, ..., 182, 151, 122],
#        [187, 192, 196, ..., 183, 153, 126],
#        ...,
#        [201, 203, 204, ..., 195, 195, 195],
#        [197, 199, 200, ..., 194, 194, 194],
#        [194, 193, 192, ..., 191, 191, 191]], dtype=uint8)

# %%
face_cascade = cv2.CascadeClassifier("./haarcascades/haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("./haarcascades/haarcascade_eye.xml")

faces = face_cascade.detectMultiScale(gray ,1.3 ,5)
faces
# Out:
# array([[ 83,  28, 102, 102]])

# %%
x,y,w,h = faces[0]

# %%
face_img = cv2.rectangle(img , (x,y) ,(x+w,y+h) , (255,0,0) , 4)
plt.imshow(face_img)

# %% [markdown]
# #### track eyes and face

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img , (x,y) ,(x+w,y+h) , (255,0,0) )
    roi_gray = gray[y:y+h , x:x+w]
    roi_color = face_img[y:y+h , x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color , (ex,ey), (ex+ew,ey+eh) ,(0,255,0) , 2)
plt.figure()
plt.imshow(face_img , cmap='gray')
plt.show()

# %% [markdown]
# #### crop face

# %%
# %matplotlib inline
plt.imshow(roi_color,cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray , 1.3 ,5)
    for (x,y,h,w) in faces :
        roi_gray = gray[y:y+h , x:x+w]
        roi_color = img[y:y+h , x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color
cropped_img = get_cropped_image_if_2_eyes("./photos/virat_kohli/images (4).jpeg")
plt.imshow(cropped_img)

# %% [markdown]
# #### create a folder of celebrities and store a croped photos inside folfer

# %%
path_to_data="./photos/"
path_to_cr_data="./photos/cropped/"
import os
img_dirs=[]
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./photos/anushka_sharma', './photos/lionel_messi', './photos/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.makedirs(path_to_cr_data)

# %%
img_dirs
# Out:
# ['./photos/anushka_sharma', './photos/lionel_messi', './photos/virat_kohli']

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# anushka_sharma
# Generating cropped images in folder:  ./photos/cropped/anushka_sharma
# lionel_messi
# Generating cropped images in folder:  ./photos/cropped/lionel_messi
# virat_kohli
# Generating cropped images in folder:  ./photos/cropped/virat_kohli

# %%
celebrity_file_names_dict
# Out:
# {'anushka_sharma': ['./photos/cropped/anushka_sharma/anushka_sharma1.png',
#   './photos/cropped/anushka_sharma/anushka_sharma2.png',
#   './photos/cropped/anushka_sharma/anushka_sharma3.png',
#   './photos/cropped/anushka_sharma/anushka_sharma4.png',
#   './photos/cropped/anushka_sharma/anushka_sharma5.png',
#   './photos/cropped/anushka_sharma/anushka_sharma6.png',
#   './photos/cropped/anushka_sharma/anushka_sharma7.png',
#   './photos/cropped/anushka_sharma/anushka_sharma8.png',
#   './photos/cropped/anushka_sharma/anushka_sharma9.png',
#   './photos/cropped/anushka_sharma/anushka_sharma10.png',
#   './photos/cropped/anushka_sharma/anushka_sharma11.png',
#   './photos/cropped/anushka_sharma/anushka_sharma12.png',
#   './photos/cropped/anushka_sharma/anushka_sharma13.png',
#   './photos/cropped/anushka_sharma/anushka_sharma14.png',
#   './photos/cropped/anushka_sharma/anushka_sharma15.png',
#   './photos/cropped/anushka_sharma/anushka_sharma16.png',
#   './photos/cropped/anushka_sharma/anushka_sharma17.png',
#   './photos/cropped/anushka_sharma/anushka_sharma18.png'],
#  'lionel_messi': ['./photos/cropped/lionel_messi/lionel_messi1.png',
#   './photos/cropped/lionel_messi/lionel_messi2.png',
#   './photos/cropped/lionel_messi/lionel_messi3.png',
#   './photos/cropped/lionel_messi/lionel_messi4.png',
#   './photos/cropped/lionel_messi/lionel_messi5.png',
#   './photos/cropped/lionel_messi/lionel_messi6.png',
#   './photos/cropped/lionel_messi/lionel_messi7.png',
#   './photos/cropped/lionel_messi/lionel_messi8.png',
#   './photos/cropped/lionel_messi/lionel_messi9.png',
#   './photos/cropped/lionel_messi/lionel_messi10.png',
#   './photos/cropped/lionel_messi/lionel_messi11.png',
#   './photos/cropped/lionel_messi/lionel_messi12.png',
#   './photos/cropped/lionel_messi/lionel_messi13.png',
#   './photos/cropped/lionel_messi/lionel_messi14.png',
#   './photos/cropped/lionel_messi/lionel_messi15.png',
#   './photos/cropped/lionel_messi/lionel_messi16.png',
#   './photos/cropped/lionel_messi/lionel_messi17.png',
#   './photos/cropped/lionel_messi/lionel_messi18.png',
#   './photos/cropped/lionel_messi/lionel_messi19.png',
#   './photos/cropped/lionel_messi/lionel_messi20.png',
#   './photos/cropped/lionel_messi/lionel_messi21.png',
#   './photos/cropped/lionel_messi/lionel_messi22.png'],
#  'virat_kohli': ['./photos/cropped/virat_kohli/virat_kohli1.png',
#   './photos/cropped/virat_kohli/virat_kohli2.png',
#   './photos/cropped/virat_kohli/virat_kohli3.png',
#   './photos/cropped/virat_kohli/virat_kohli4.png',
#   './photos/cropped/virat_kohli/virat_kohli5.png',
#   './photos/cropped/virat_kohli/virat_kohli6.png',
#   './photos/cropped/virat_kohli/virat_kohli7.png',
#   './photos/cropped/virat_kohli/virat_kohli8.png',
#   './photos/cropped/virat_kohli/virat_kohli9.png',
#   './photos/cropped/virat_kohli/virat_kohli10.png',
#   './photos/cropped/virat_kohli/virat_kohli11.png',
#   './photos/cropped/virat_kohli/virat_kohli12.png',
#   './photos/cropped/virat_kohli/virat_kohli13.png',
#   './photos/cropped/virat_kohli/virat_kohli14.png',
#   './photos/cropped/virat_kohli/virat_kohli15.png',
#   './photos/cropped/virat_kohli/virat_kohli16.png',
#   './photos/cropped/virat_kohli/virat_kohli17.png',
#   './photos/cropped/virat_kohli/virat_kohli18.png',
#   './photos/cropped/virat_kohli/virat_kohli19.png',
#   './photos/cropped/virat_kohli/virat_kohli20.png',
#   './photos/cropped/virat_kohli/virat_kohli21.png',
#   './photos/cropped/virat_kohli/virat_kohli22.png',
#   './photos/cropped/virat_kohli/virat_kohli23.png',
#   './photos/cropped/virat_kohli/virat_kohli24.png']}

# %% [markdown]
# #### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# #### Manually examine cropped folder and delete any unwanted images

# %%
cropped_image_dirs
# Out:
# ['./photos/cropped/anushka_sharma',
#  './photos/cropped/lionel_messi',
#  './photos/cropped/virat_kohli']

# %% [markdown]
# ## (3) Preprocessing: Use wavelet transform as a feature for traning our model

# %% [markdown]
# ### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
class_dic={}
count=0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dic[celebrity_name]=count
    count=count+1
class_dic
# Out:
# {'anushka_sharma': 0, 'lionel_messi': 1, 'virat_kohli': 2}

# %%
X=[]
y=[]
for celebrity_name,training_files in celebrity_file_names_dict.items():
    for training_img in training_files:
        img = cv2.imread(training_img)
        scalled_raw_img = cv2.resize(img , (32,32))
        img_har = w2d(scalled_raw_img , 'db1' , 5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dic[celebrity_name])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (64, 4096)

# %% [markdown]
# ## Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# ### We will use SVM with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.875

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       0.86      0.86      0.86         7
#            2       0.83      0.83      0.83         6
#
#     accuracy                           0.88        16
#    macro avg       0.90      0.90      0.90        16
# weighted avg       0.88      0.88      0.88        16

# %% [markdown]
# ### Grid search CV

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.873333
# 1        random_forest    0.768889
# 2  logistic_regression    0.851111
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %% [markdown]
# #### After above conclusion logistic and svm is best performer

# %%
best_clf = best_estimators['svm']
import joblib
joblib.dump(best_clf,'save_model.pkl')
# Out:
# ['save_model.pkl']

# %%
class_dic
# Out:
# {'anushka_sharma': 0, 'lionel_messi': 1, 'virat_kohli': 2}

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dic))
